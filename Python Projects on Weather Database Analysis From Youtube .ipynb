# %%
import pandas as pd

# %%
Data_Set = pd.read_csv("../Desktop/Python/DATASET/Weather DAtaset.zip")

# %%
Data_Set
# Out:
#      Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0             0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1             1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2             2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3             3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4             4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
# ..          ...   ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112         112  2013  18.88  21.07  24.53  26.97  29.06  28.24  27.50  27.22
# 113         113  2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42
# 114         114  2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64
# 115         115  2016  20.92  23.58  26.61  29.56  30.41  29.70  28.18  28.17
# 116         116  2017  20.59  23.08  25.58  29.17  30.47  29.44  28.31  28.12
#
#        SEP    OCT    NOV    DEC
# ...

# %%
Data_Set.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0             0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1             1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2             2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3             3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4             4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
# ..          ...   ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112         112  2013  18.88  21.07  24.53  26.97  29.06  28.24  27.50  27.22
# 113         113  2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42
# 114         114  2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64
# 115         115  2016  20.92  23.58  26.61  29.56  30.41  29.70  28.18  28.17
# 116         116  2017  20.59  23.08  25.58  29.17  30.47  29.44  28.31  28.12
#
# ...

# %%
Data_Set.shape
# Out:
# (117, 14)

# %%
Data_Set.append
# Out:
# <bound method DataFrame.append of      Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0             0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1             1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2             2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3             3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4             4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
# ..          ...   ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112         112  2013  18.88  21.07  24.53  26.97  29.06  28.24  27.50  27.22
# 113         113  2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42
# 114         114  2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64
# 115         115  2016  20.92  23.58  26.61  29.56  30.41  29.70  28.18  28.17
# 116         116  2017  20.59  23.08  25.58  29.17  30.47  29.44  28.31  28.12
#
# ...

# %%
Data_Set.applymap
# Out:
# <bound method DataFrame.applymap of      Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0             0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1             1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2             2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3             3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4             4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
# ..          ...   ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112         112  2013  18.88  21.07  24.53  26.97  29.06  28.24  27.50  27.22
# 113         113  2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42
# 114         114  2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64
# 115         115  2016  20.92  23.58  26.61  29.56  30.41  29.70  28.18  28.17
# 116         116  2017  20.59  23.08  25.58  29.17  30.47  29.44  28.31  28.12
# ...

# %%
Data_Set.shape
# Out:
# (117, 14)

# %%
Data_Set.index
# Out:
# RangeIndex(start=0, stop=117, step=1)

# %%
Data_Set.columns
# Out:
# Index(['Unnamed: 0', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC'],
#       dtype='object')

# %%
Data_Set.dtypes
# Out:
# Unnamed: 0      int64
# YEAR            int64
# JAN           float64
# FEB           float64
# MAR           float64
# APR           float64
# MAY           float64
# JUN           float64
# JUL           float64
# AUG           float64
# SEP           float64
# OCT           float64
# NOV           float64
# DEC           float64
# dtype: object

# %%
Data_Set.nunique
# Out:
# <bound method DataFrame.nunique of      Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0             0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1             1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2             2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3             3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4             4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
# ..          ...   ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112         112  2013  18.88  21.07  24.53  26.97  29.06  28.24  27.50  27.22
# 113         113  2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42
# 114         114  2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64
# 115         115  2016  20.92  23.58  26.61  29.56  30.41  29.70  28.18  28.17
# 116         116  2017  20.59  23.08  25.58  29.17  30.47  29.44  28.31  28.12
#
# ...

# %%
Data_Set.nunique()
# Out:
# Unnamed: 0    117
# YEAR          117
# JAN            89
# FEB            92
# MAR            93
# APR            99
# MAY            86
# JUN            84
# JUL            76
# AUG            80
# SEP            74
# OCT            82
# NOV            95
# DEC            88
# dtype: int64

# %%
Data_Set['JUN'].unique
# Out:
# <bound method Series.unique of 0      28.60
# 1      28.44
# 2      28.41
# 3      27.85
# 4      28.69
#        ...
# 112    28.24
# 113    29.42
# 114    28.15
# 115    29.70
# 116    29.44
# Name: JUN, Length: 117, dtype: float64>

# %%
Data_Set['JAN'].unique()
# Out:
# array([17.99, 19.  , 18.32, 17.77, 17.4 , 17.5 , 19.27, 18.35, 17.79,
#        18.14, 18.52, 18.6 , 18.2 , 18.96, 17.93, 18.16, 17.25, 18.78,
#        18.27, 18.61, 18.3 , 18.23, 18.06, 17.53, 18.65, 18.15, 18.66,
#        18.25, 17.75, 19.34, 18.72, 17.84, 17.8 , 17.54, 18.02, 18.4 ,
#        18.1 , 18.33, 18.07, 18.  , 17.33, 18.31, 17.72, 19.01, 18.36,
#        19.09, 18.67, 18.11, 18.42, 18.01, 19.5 , 18.39, 18.89, 17.59,
#        17.71, 18.47, 18.69, 17.52, 18.12, 18.51, 18.97, 18.81, 18.76,
#        18.38, 18.28, 18.24, 18.44, 18.58, 17.68, 18.56, 18.37, 19.33,
#        19.18, 19.81, 17.86, 18.84, 18.87, 18.5 , 18.83, 19.07, 19.96,
#        19.24, 18.49, 19.79, 19.15, 18.88, 19.02, 20.92, 20.59])

# %%
Data_Set.nunique()
# Out:
# Unnamed: 0    117
# YEAR          117
# JAN            89
# FEB            92
# MAR            93
# APR            99
# MAY            86
# JUN            84
# JUL            76
# AUG            80
# SEP            74
# OCT            82
# NOV            95
# DEC            88
# dtype: int64

# %%
Data_Set.count
# Out:
# <bound method DataFrame.count of      Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0             0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1             1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2             2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3             3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4             4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
# ..          ...   ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112         112  2013  18.88  21.07  24.53  26.97  29.06  28.24  27.50  27.22
# 113         113  2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42
# 114         114  2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64
# 115         115  2016  20.92  23.58  26.61  29.56  30.41  29.70  28.18  28.17
# 116         116  2017  20.59  23.08  25.58  29.17  30.47  29.44  28.31  28.12
#
# ...

# %%
Data_Set.count()
# Out:
# Unnamed: 0    117
# YEAR          117
# JAN           117
# FEB           117
# MAR           117
# APR           117
# MAY           117
# JUN           117
# JUL           117
# AUG           117
# SEP           117
# OCT           117
# NOV           117
# DEC           117
# dtype: int64

# %%
Data_Set.value_counts
# Out:
# <bound method DataFrame.value_counts of      Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0             0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1             1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2             2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3             3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4             4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
# ..          ...   ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112         112  2013  18.88  21.07  24.53  26.97  29.06  28.24  27.50  27.22
# 113         113  2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42
# 114         114  2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64
# 115         115  2016  20.92  23.58  26.61  29.56  30.41  29.70  28.18  28.17
# ...

# %%
Data_Set.value_counts()
# Out:
# Unnamed: 0  YEAR  JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC
# 0           1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98  26.26  25.08  21.73  18.95    1
# 74          1975  17.71  19.67  22.78  26.39  28.16  27.72  26.48  26.47  25.63  24.65  20.76  18.51    1
# 86          1987  18.44  20.41  23.45  26.59  27.51  28.90  28.16  27.34  27.13  25.03  22.14  19.75    1
# 85          1986  18.24  20.00  23.53  26.53  27.75  28.19  27.30  26.75  26.43  24.48  21.89  19.38    1
# 84          1985  18.67  20.54  24.60  27.02  28.52  28.05  27.06  26.90  26.45  24.33  21.51  19.68    1
#                                                                                                        ..
# 35          1936  18.06  20.00  22.84  26.27  28.97  27.41  27.12  26.80  26.44  24.73  21.72  19.13    1
# 34          1935  17.54  21.00  23.39  25.15  28.88  28.45  27.18  26.37  25.85  24.42  21.49  19.03    1
# ...

# %%
Data_Set.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0             0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1             1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2             2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3             3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4             4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
# ..          ...   ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112         112  2013  18.88  21.07  24.53  26.97  29.06  28.24  27.50  27.22
# 113         113  2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42
# 114         114  2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64
# 115         115  2016  20.92  23.58  26.61  29.56  30.41  29.70  28.18  28.17
# 116         116  2017  20.59  23.08  25.58  29.17  30.47  29.44  28.31  28.12
#
# ...

# %%
Data_Set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  117 non-null    int64
#  1   YEAR        117 non-null    int64
#  2   JAN         117 non-null    float64
#  3   FEB         117 non-null    float64
#  4   MAR         117 non-null    float64
#  5   APR         117 non-null    float64
#  6   MAY         117 non-null    float64
#  7   JUN         117 non-null    float64
#  8   JUL         117 non-null    float64
#  9   AUG         117 non-null    float64
#  10  SEP         117 non-null    float64
#  11  OCT         117 non-null    float64
#  12  NOV         117 non-null    float64
#  13  DEC         117 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 12.9 KB

# %%
Data_Set.head()
# Out:
#    Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0           0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1           1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2           2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3           3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4           4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
#
#      SEP    OCT    NOV    DEC
# 0  26.26  25.08  21.73  18.95
# 1  25.95  24.37  21.33  18.78
# 2  26.34  24.57  20.96  18.29
# 3  25.84  24.36  21.07  18.84
# 4  26.29  26.16  22.07  18.71

# %%
Data_Set.head(5)
# Out:
#    Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0           0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1           1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2           2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3           3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4           4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
#
#      SEP    OCT    NOV    DEC
# 0  26.26  25.08  21.73  18.95
# 1  25.95  24.37  21.33  18.78
# 2  26.34  24.57  20.96  18.29
# 3  25.84  24.36  21.07  18.84
# 4  26.29  26.16  22.07  18.71

# %%
Data_Set.nunique()
# Out:
# Unnamed: 0    117
# YEAR          117
# JAN            89
# FEB            92
# MAR            93
# APR            99
# MAY            86
# JUN            84
# JUL            76
# AUG            80
# SEP            74
# OCT            82
# NOV            95
# DEC            88
# dtype: int64

# %%
Data_Set['SEP'].unique()
# Out:
# array([26.26, 25.95, 26.34, 25.84, 26.29, 26.23, 25.74, 25.47, 25.98,
#        26.22, 25.81, 26.02, 26.38, 26.82, 26.  , 25.79, 25.92, 26.04,
#        25.89, 25.72, 26.1 , 26.32, 26.41, 26.17, 26.25, 26.5 , 25.86,
#        26.56, 25.85, 26.44, 26.43, 26.14, 26.4 , 26.19, 26.03, 26.08,
#        26.51, 26.31, 26.28, 25.6 , 26.72, 26.48, 26.24, 26.37, 26.27,
#        26.33, 26.45, 25.99, 26.35, 26.61, 26.21, 25.63, 26.55, 26.36,
#        25.83, 27.13, 26.65, 26.11, 27.15, 26.64, 26.81, 26.7 , 26.9 ,
#        26.53, 26.86, 26.75, 26.8 , 26.42, 27.11, 26.6 , 26.87, 27.04,
#        27.72, 28.11])

# %%
Data_Set['SEP'].nunique()
# Out:
# 74

# %%
Data_Set.head(5)
# Out:
#    Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0           0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1           1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2           2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3           3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4           4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
#
#      SEP    OCT    NOV    DEC
# 0  26.26  25.08  21.73  18.95
# 1  25.95  24.37  21.33  18.78
# 2  26.34  24.57  20.96  18.29
# 3  25.84  24.36  21.07  18.84
# 4  26.29  26.16  22.07  18.71

# %%
Data_Set.value_counts()
# Out:
# Unnamed: 0  YEAR  JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC
# 0           1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98  26.26  25.08  21.73  18.95    1
# 74          1975  17.71  19.67  22.78  26.39  28.16  27.72  26.48  26.47  25.63  24.65  20.76  18.51    1
# 86          1987  18.44  20.41  23.45  26.59  27.51  28.90  28.16  27.34  27.13  25.03  22.14  19.75    1
# 85          1986  18.24  20.00  23.53  26.53  27.75  28.19  27.30  26.75  26.43  24.48  21.89  19.38    1
# 84          1985  18.67  20.54  24.60  27.02  28.52  28.05  27.06  26.90  26.45  24.33  21.51  19.68    1
#                                                                                                        ..
# 35          1936  18.06  20.00  22.84  26.27  28.97  27.41  27.12  26.80  26.44  24.73  21.72  19.13    1
# 34          1935  17.54  21.00  23.39  25.15  28.88  28.45  27.18  26.37  25.85  24.42  21.49  19.03    1
# ...

# %%
Data_Set.JAN.value_counts()
# Out:
# 18.32    4
# 18.40    3
# 18.25    3
# 18.20    3
# 18.15    3
#         ..
# 18.01    1
# 19.50    1
# 18.39    1
# 18.16    1
# 20.59    1
# Name: JAN, Length: 89, dtype: int64

# %%
Data_Set.head(5)
# Out:
#    Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0           0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1           1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2           2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3           3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4           4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
#
#      SEP    OCT    NOV    DEC
# 0  26.26  25.08  21.73  18.95
# 1  25.95  24.37  21.33  18.78
# 2  26.34  24.57  20.96  18.29
# 3  25.84  24.36  21.07  18.84
# 4  26.29  26.16  22.07  18.71

# %%
Data_Set.JAN
# Out:
# 0      17.99
# 1      19.00
# 2      18.32
# 3      17.77
# 4      17.40
#        ...
# 112    18.88
# 113    18.81
# 114    19.02
# 115    20.92
# 116    20.59
# Name: JAN, Length: 117, dtype: float64

# %%
Data_Set.JUN == 'Clear'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 112    False
# 113    False
# 114    False
# 115    False
# 116    False
# Name: JUN, Length: 117, dtype: bool

# %%
 Data_Set.head()
# Out:
#    Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0           0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1           1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2           2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3           3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4           4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
#
#      SEP    OCT    NOV    DEC
# 0  26.26  25.08  21.73  18.95
# 1  25.95  24.37  21.33  18.78
# 2  26.34  24.57  20.96  18.29
# 3  25.84  24.36  21.07  18.84
# 4  26.29  26.16  22.07  18.71

# %%
Data_Set.groupby
# Out:
# <bound method DataFrame.groupby of      Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0             0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1             1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2             2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3             3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4             4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
# ..          ...   ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112         112  2013  18.88  21.07  24.53  26.97  29.06  28.24  27.50  27.22
# 113         113  2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42
# 114         114  2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64
# 115         115  2016  20.92  23.58  26.61  29.56  30.41  29.70  28.18  28.17
# 116         116  2017  20.59  23.08  25.58  29.17  30.47  29.44  28.31  28.12
#
# ...

# %%
Data_Set.groupby('JUN').get_group('Clear')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21668/1046607385.py in <module>
# ----> 1 Data_Set.groupby('JUN').get_group('Clear')
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in get_group(self, name, obj)
#     752         inds = self._get_index(name)
#     753         if not len(inds):
# --> 754             raise KeyError(name)
#     755
#     756         return obj._take_with_is_copy(inds, axis=self.axis)
#
# KeyError: 'Clear'

# %%
Data_Set.head(5)
# Out:
#    Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0           0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1           1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2           2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3           3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4           4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
#
#      SEP    OCT    NOV    DEC
# 0  26.26  25.08  21.73  18.95
# 1  25.95  24.37  21.33  18.78
# 2  26.34  24.57  20.96  18.29
# 3  25.84  24.36  21.07  18.84
# 4  26.29  26.16  22.07  18.71

# %%
Data_Set['JUN'] == 5
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 112    False
# 113    False
# 114    False
# 115    False
# 116    False
# Name: JUN, Length: 117, dtype: bool

# %%
Data_Set[Data_Set['JUN']  == 2 ]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, YEAR, JAN, FEB, MAR, APR, MAY, JUN, JUL, AUG, SEP, OCT, NOV, DEC]
# Index: []

# %%
Data_Set.isnull()
# Out:
#      Unnamed: 0   YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL  \
# 0         False  False  False  False  False  False  False  False  False
# 1         False  False  False  False  False  False  False  False  False
# 2         False  False  False  False  False  False  False  False  False
# 3         False  False  False  False  False  False  False  False  False
# 4         False  False  False  False  False  False  False  False  False
# ..          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112       False  False  False  False  False  False  False  False  False
# 113       False  False  False  False  False  False  False  False  False
# 114       False  False  False  False  False  False  False  False  False
# 115       False  False  False  False  False  False  False  False  False
# 116       False  False  False  False  False  False  False  False  False
#
#        AUG    SEP    OCT    NOV    DEC
# 0    False  False  False  False  False
# ...

# %%
Data_Set.isnull().sum()
# Out:
# Unnamed: 0    0
# YEAR          0
# JAN           0
# FEB           0
# MAR           0
# APR           0
# MAY           0
# JUN           0
# JUL           0
# AUG           0
# SEP           0
# OCT           0
# NOV           0
# DEC           0
# dtype: int64

# %%
Data_Set.notnull()
# Out:
#      Unnamed: 0  YEAR   JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP  \
# 0          True  True  True  True  True  True  True  True  True  True  True
# 1          True  True  True  True  True  True  True  True  True  True  True
# 2          True  True  True  True  True  True  True  True  True  True  True
# 3          True  True  True  True  True  True  True  True  True  True  True
# 4          True  True  True  True  True  True  True  True  True  True  True
# ..          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 112        True  True  True  True  True  True  True  True  True  True  True
# 113        True  True  True  True  True  True  True  True  True  True  True
# 114        True  True  True  True  True  True  True  True  True  True  True
# 115        True  True  True  True  True  True  True  True  True  True  True
# 116        True  True  True  True  True  True  True  True  True  True  True
#
#       OCT   NOV   DEC
# 0    True  True  True
# ...

# %%
Data_Set.notnull().sum()
# Out:
# Unnamed: 0    117
# YEAR          117
# JAN           117
# FEB           117
# MAR           117
# APR           117
# MAY           117
# JUN           117
# JUL           117
# AUG           117
# SEP           117
# OCT           117
# NOV           117
# DEC           117
# dtype: int64

# %%
Data_Set.head(5)
# Out:
#    Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0           0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1           1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2           2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3           3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4           4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
#
#      SEP    OCT    NOV    DEC
# 0  26.26  25.08  21.73  18.95
# 1  25.95  24.37  21.33  18.78
# 2  26.34  24.57  20.96  18.29
# 3  25.84  24.36  21.07  18.84
# 4  26.29  26.16  22.07  18.71

# %%
Data_Set.rename
# Out:
# <bound method DataFrame.rename of      Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0             0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1             1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2             2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3             3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4             4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
# ..          ...   ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112         112  2013  18.88  21.07  24.53  26.97  29.06  28.24  27.50  27.22
# 113         113  2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42
# 114         114  2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64
# 115         115  2016  20.92  23.58  26.61  29.56  30.41  29.70  28.18  28.17
# 116         116  2017  20.59  23.08  25.58  29.17  30.47  29.44  28.31  28.12
#
# ...

# %%
Data_Set.rename(columns = {'JUN' :'ROMIO'})
# Out:
#      Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY  ROMIO    JUL    AUG  \
# 0             0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1             1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2             2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3             3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4             4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
# ..          ...   ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112         112  2013  18.88  21.07  24.53  26.97  29.06  28.24  27.50  27.22
# 113         113  2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42
# 114         114  2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64
# 115         115  2016  20.92  23.58  26.61  29.56  30.41  29.70  28.18  28.17
# 116         116  2017  20.59  23.08  25.58  29.17  30.47  29.44  28.31  28.12
#
#        SEP    OCT    NOV    DEC
# ...

# %%
Data_Set.head()
# Out:
#    Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0           0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1           1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2           2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3           3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4           4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
#
#      SEP    OCT    NOV    DEC
# 0  26.26  25.08  21.73  18.95
# 1  25.95  24.37  21.33  18.78
# 2  26.34  24.57  20.96  18.29
# 3  25.84  24.36  21.07  18.84
# 4  26.29  26.16  22.07  18.71

# %%
Data_Set.rename(columns={'ROMIO' : 'JUN'},inplace=True)

# %%
Data_Set.head()
# Out:
#    Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0           0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1           1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2           2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3           3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4           4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
#
#      SEP    OCT    NOV    DEC
# 0  26.26  25.08  21.73  18.95
# 1  25.95  24.37  21.33  18.78
# 2  26.34  24.57  20.96  18.29
# 3  25.84  24.36  21.07  18.84
# 4  26.29  26.16  22.07  18.71

# %%
Data_Set.head(5)
# Out:
#    Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0           0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1           1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2           2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3           3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4           4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
#
#      SEP    OCT    NOV    DEC
# 0  26.26  25.08  21.73  18.95
# 1  25.95  24.37  21.33  18.78
# 2  26.34  24.57  20.96  18.29
# 3  25.84  24.36  21.07  18.84
# 4  26.29  26.16  22.07  18.71

# %%
Data_Set.JUN.mean()
# Out:
# 28.300940170940162

# %%
Data_Set.JAN.mean()
# Out:
# 18.42324786324786

# %%
 Data_Set.std()
# Out:
# Unnamed: 0    33.919021
# YEAR          33.919021
# JAN            0.612963
# FEB            0.900944
# MAR            0.862825
# APR            0.750740
# MAY            0.644678
# JUN            0.460603
# JUL            0.345920
# AUG            0.348876
# SEP            0.387789
# OCT            0.563152
# NOV            0.634183
# DEC            0.635912
# dtype: float64

# %%
Data_Set.JAN.std()
# Out:
# 0.6129631662723316

# %%
Data_Set['JUN'].var
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.var of 0      28.60
# 1      28.44
# 2      28.41
# 3      27.85
# 4      28.69
#        ...
# 112    28.24
# 113    29.42
# 114    28.15
# 115    29.70
# 116    29.44
# Name: JUN, Length: 117, dtype: float64>

# %%
Data_Set['JUN'].var()
# Out:
# 0.21215514294134982

# %%
Data_Set.head(5)
# Out:
#    Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0           0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1           1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2           2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3           3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4           4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47
#
#      SEP    OCT    NOV    DEC
# 0  26.26  25.08  21.73  18.95
# 1  25.95  24.37  21.33  18.78
# 2  26.34  24.57  20.96  18.29
# 3  25.84  24.36  21.07  18.84
# 4  26.29  26.16  22.07  18.71

# %%
Data_Set['JUN'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      28.60
# 1      28.44
# 2      28.41
# 3      27.85
# 4      28.69
#        ...
# 112    28.24
# 113    29.42
# 114    28.15
# 115    29.70
# 116    29.44
# Name: JUN, Length: 117, dtype: float64>

# %%
Data_Set['JUN'].value_counts()
# Out:
# 28.60    4
# 28.02    3
# 28.25    3
# 27.86    3
# 27.72    3
#         ..
# 28.21    1
# 28.79    1
# 28.28    1
# 28.01    1
# 29.44    1
# Name: JUN, Length: 84, dtype: int64

# %%
 Data_Set['JUN'] == 'JULIYA'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 112    False
# 113    False
# 114    False
# 115    False
# 116    False
# Name: JUN, Length: 117, dtype: bool

# %%
Data_Set['JUN'].str.contains('RAM')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21668/3852641675.py in <module>
# ----> 1 Data_Set['JUN'].str.contains('RAM')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
Data_Set[Data_Set['JUL'].str.contains('APALA')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21668/1143991373.py in <module>
# ----> 1 Data_Set[Data_Set['JUL'].str.contains('APALA')]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
Data_Set.tail(50)
# Out:
#      Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 67           67  1968  17.52  18.98  23.18  25.89  27.77  28.24  27.12  26.90
# 68           68  1969  18.07  20.30  24.52  26.70  27.93  28.68  27.47  26.97
# 69           69  1970  18.72  20.39  23.28  27.17  28.71  27.86  27.25  26.84
# 70           70  1971  18.12  19.99  23.29  26.48  27.58  27.58  26.87  26.53
# 71           71  1972  18.40  18.73  23.43  25.85  28.08  28.70  27.37  26.76
# 72           72  1973  18.51  20.98  23.33  27.54  28.71  28.62  27.54  26.61
# 73           73  1974  17.79  19.28  23.91  27.01  27.81  27.89  27.07  26.91
# 74           74  1975  17.71  19.67  22.78  26.39  28.16  27.72  26.48  26.47
# 75           75  1976  18.20  19.54  22.98  25.92  27.94  27.86  27.34  26.21
# 76           76  1977  18.35  20.34  24.45  26.38  27.26  28.04  27.26  26.88
# 77           77  1978  18.14  19.76  22.46  26.44  28.92  28.42  27.04  26.80
# ...

# %%
Data_Set.convert_dtypes('int')
# Out:
#      Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0             0  1901  17.99  19.43  23.49  26.41  28.28   28.6  27.49  26.98
# 1             1  1902   19.0  20.39   24.1  26.54  28.68  28.44  27.29  27.05
# 2             2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
# 3             3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73
# 4             4  1905   17.4  17.79  21.78  24.84  28.32  28.69  27.67  27.47
# ..          ...   ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112         112  2013  18.88  21.07  24.53  26.97  29.06  28.24   27.5  27.22
# 113         113  2014  18.81  20.35  23.34  26.91  28.45  29.42  28.07  27.42
# 114         114  2015  19.02  21.23  23.52  26.52  28.82  28.15  28.03  27.64
# 115         115  2016  20.92  23.58  26.61  29.56  30.41   29.7  28.18  28.17
# 116         116  2017  20.59  23.08  25.58  29.17  30.47  29.44  28.31  28.12
#
#        SEP    OCT    NOV    DEC
# ...

# %%
Data_Set['JUN'].str.contains('APALA')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21668/2871933177.py in <module>
# ----> 1 Data_Set['JUN'].str.contains('APALA')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
Data_Set['JUN'].str('APALA')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21668/1960480490.py in <module>
# ----> 1 Data_Set['JUN'].str('APALA')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
Data_Set.head(3)
# Out:
#    Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0           0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1           1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2           2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
#
#      SEP    OCT    NOV    DEC
# 0  26.26  25.08  21.73  18.95
# 1  25.95  24.37  21.33  18.78
# 2  26.34  24.57  20.96  18.29

# %%
Data_Set[(Data_Set["JUN"] > 25) & (Data_Set['SEP']  == 23)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, YEAR, JAN, FEB, MAR, APR, MAY, JUN, JUL, AUG, SEP, OCT, NOV, DEC]
# Index: []

# %%
Data_Set.head(3)
# Out:
#    Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0           0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1           1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2           2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
#
#      SEP    OCT    NOV    DEC
# 0  26.26  25.08  21.73  18.95
# 1  25.95  24.37  21.33  18.78
# 2  26.34  24.57  20.96  18.29

# %%
Data_Set.groupby('DEC').mean()
# Out:
#        Unnamed: 0    YEAR     JAN    FEB     MAR     APR     MAY    JUN  \
# DEC
# 17.98        44.0  1945.0  17.330  19.37  23.280  25.520  28.310  28.81
# 18.05         9.0  1910.0  18.140  19.72  22.900  25.960  28.360  27.72
# 18.09        36.0  1937.0  18.020  20.21  22.600  25.830  28.400  28.69
# 18.15         7.0  1908.0  18.350  19.73  22.930  27.060  28.070  28.49
# 18.17        44.0  1945.0  18.155  19.48  24.075  26.925  27.985  27.85
# ...           ...     ...     ...    ...     ...     ...     ...    ...
# 20.22       108.0  2009.0  19.790  21.66  24.550  27.350  28.710  28.77
# 20.62       107.0  2008.0  18.490  19.83  24.430  26.540  28.420  28.10
# 20.65        94.0  1995.0  19.180  21.48  24.260  27.230  29.340  29.88
# 21.47       116.0  2017.0  20.590  23.08  25.580  29.170  30.470  29.44
# 21.89       115.0  2016.0  20.920  23.58  26.610  29.560  30.410  29.70
#
#           JUL    AUG     SEP     OCT    NOV
# DEC
# 17.98  27.390  26.98  26.510  24.360  21.15
# ...

# %%
Data_Set.groupby('JAN').mean()
# Out:
#        Unnamed: 0    YEAR    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# JAN
# 17.25        17.0  1918.0  19.58  22.64  25.26  28.27  27.58  27.74  26.97
# 17.33        44.0  1945.0  19.37  23.28  25.52  28.31  28.81  27.39  26.98
# 17.40         4.0  1905.0  17.79  21.78  24.84  28.32  28.69  27.67  27.47
# 17.50         5.0  1906.0  19.14  22.21  26.53  29.06  28.02  27.46  26.82
# 17.52        67.0  1968.0  18.98  23.18  25.89  27.77  28.24  27.12  26.90
# ...           ...     ...    ...    ...    ...    ...    ...    ...    ...
# 19.79       108.0  2009.0  21.66  24.55  27.35  28.71  28.77  27.83  27.85
# 19.81        95.0  1996.0  21.73  25.13  26.67  28.37  28.08  27.42  26.77
# 19.96       105.0  2006.0  23.02  23.91  26.83  28.82  28.13  27.92  27.15
# 20.59       116.0  2017.0  23.08  25.58  29.17  30.47  29.44  28.31  28.12
# 20.92       115.0  2016.0  23.58  26.61  29.56  30.41  29.70  28.18  28.17
#
#          SEP    OCT    NOV    DEC
# JAN
# ...

# %%
Data_Set.head(3)
# Out:
#    Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0           0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1           1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2           2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
#
#      SEP    OCT    NOV    DEC
# 0  26.26  25.08  21.73  18.95
# 1  25.95  24.37  21.33  18.78
# 2  26.34  24.57  20.96  18.29

# %%
Data_Set.groupby('JUN').min()
# Out:
#        Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUL    AUG  \
# JUN
# 27.33          37  1938  18.15  18.77  23.61  26.91  28.97  27.16  26.83
# 27.41          16  1917  18.06  19.94  22.46  25.29  26.97  27.12  26.64
# 27.54          55  1956  18.01  19.66  23.44  26.72  28.72  26.58  26.23
# 27.58          17  1918  17.25  19.58  22.64  25.26  27.58  26.87  26.53
# 27.66           6  1907  19.27  19.42  22.03  26.98  27.52  27.28  26.38
# ...           ...   ...    ...    ...    ...    ...    ...    ...    ...
# 29.01          57  1958  18.60  20.51  23.62  27.23  28.20  27.53  26.74
# 29.42         113  2014  18.81  20.35  23.34  26.91  28.45  28.07  27.42
# 29.44         116  2017  20.59  23.08  25.58  29.17  30.47  28.31  28.12
# 29.70         115  2016  20.92  23.58  26.61  29.56  30.41  28.18  28.17
# 29.88          94  1995  19.18  21.48  24.26  27.23  29.34  27.80  27.40
#
#          SEP    OCT    NOV    DEC
# JUN
# 27.33  26.14  24.41  20.62  18.90
# ...

# %%
Data_Set.groupby('JUN').max()
# Out:
#        Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUL    AUG  \
# JUN
# 27.33          37  1938  18.15  18.77  23.61  26.91  28.97  27.16  26.83
# 27.41          35  1936  18.16  20.00  22.84  26.27  28.97  27.15  26.80
# 27.54          55  1956  18.01  19.66  23.44  26.72  28.72  26.58  26.23
# 27.58          70  1971  18.12  19.99  23.29  26.48  28.27  27.74  26.97
# 27.66           6  1907  19.27  19.42  22.03  26.98  27.52  27.28  26.38
# ...           ...   ...    ...    ...    ...    ...    ...    ...    ...
# 29.01         102  2003  19.50  21.03  23.93  27.29  28.64  27.60  27.25
# 29.42         113  2014  18.81  20.35  23.34  26.91  28.45  28.07  27.42
# 29.44         116  2017  20.59  23.08  25.58  29.17  30.47  28.31  28.12
# 29.70         115  2016  20.92  23.58  26.61  29.56  30.41  28.18  28.17
# 29.88          94  1995  19.18  21.48  24.26  27.23  29.34  27.80  27.40
#
#          SEP    OCT    NOV    DEC
# JUN
# 27.33  26.14  24.41  20.62  18.90
# ...

# %%
Data_Set['JUN'] == 'ROMIO'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 112    False
# 113    False
# 114    False
# 115    False
# 116    False
# Name: JUN, Length: 117, dtype: bool

# %%
Data_Set[Data_Set['JUN'] == 'ROMIO']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, YEAR, JAN, FEB, MAR, APR, MAY, JUN, JUL, AUG, SEP, OCT, NOV, DEC]
# Index: []

# %%
(Data_Set['NOV'] == 'Clear') | (Data_Set['FEB'] > 90)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 112    False
# 113    False
# 114    False
# 115    False
# 116    False
# Length: 117, dtype: bool

# %%
Data_Set(Data_Set['NOV'] == 'Clear') | (Data_Set['FEB'] > 90).tail()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21668/1403908712.py in <module>
# ----> 1 Data_Set(Data_Set['NOV'] == 'Clear') | (Data_Set['FEB'] > 90).tail()
#
# TypeError: 'DataFrame' object is not callable

# %%
Data_Set.head(3)
# Out:
#    Unnamed: 0  YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG  \
# 0           0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98
# 1           1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05
# 2           2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63
#
#      SEP    OCT    NOV    DEC
# 0  26.26  25.08  21.73  18.95
# 1  25.95  24.37  21.33  18.78
# 2  26.34  24.57  20.96  18.29

# %%
Data_Set(Data_Set['JUN'] == 'Clear') & (Data_Set['SEP'] > 50) |  (Data_Set['NOV'] > 40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21668/464238334.py in <module>
# ----> 1 Data_Set(Data_Set['JUN'] == 'Clear') & (Data_Set['SEP'] > 50) |  (Data_Set['NOV'] > 40)
#
# TypeError: 'DataFrame' object is not callable
